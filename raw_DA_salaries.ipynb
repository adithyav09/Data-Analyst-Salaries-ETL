# %% [markdown]
# - Delete Job description, company revenue, competitors, Easy apply, Founded, Rating, HQ
# - Modify ranges for salary, employee size,

# %%
#Import dependencies
import pandas as pd

# %%
df = pd.read_csv('DataAnalyst.csv', index_col=0)
df = df.drop(['Job Description', 'Revenue', 'Competitors', 'Easy Apply','Founded', 'Rating', 'Headquarters'], axis=1)
df.head(1)
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
#
#               Salary Estimate                    Company Name      Location  \
# 0  $37K-$66K (Glassdoor est.)  Vera Institute of Justice\n3.2  New York, NY
#
#                    Size       Type of ownership           Industry      Sector
# 0  201 to 500 employees  Nonprofit Organization  Social Assistance  Non-Profit

# %%
df.to_csv('cleaned_DA_salar')
